# %%
import pandas as pd
df = pd.read_parquet("genres_clean.parquet")

#création d'un dictionnaire avec les id des genres en clé et les noms des genres en valeur
genres_dict = dict(zip(df["genreId"], df["name"]))
print(genres_dict)
# Out:
# {16: 'Animation', 35: 'Comedy', 10751: 'Family', 12: 'Adventure', 14: 'Fantasy', 10749: 'Romance', 18: 'Drama', 28: 'Action', 80: 'Crime', 53: 'Thriller', 27: 'Horror', 36: 'History', 878: 'Science Fiction', 9648: 'Mystery', 10752: 'War', 10769: 'Foreign', 10402: 'Music', 99: 'Documentary', 37: 'Western', 10770: 'TV Movie'}

# %%
#transformation du csv en parquet
df = pd.read_csv("movies_cleaned.csv")
df["releaseDate"] = pd.to_datetime(df["releaseDate"], errors="coerce")
df["voteCount"] = pd.to_numeric(df["voteCount"], errors="coerce")
df["voteAverage"] = pd.to_numeric(df["voteAverage"], errors="coerce")

df.to_parquet("movies_clean.parquet", index=False)

# %%
movies = pd.read_parquet("movies_clean.parquet")
titles = movies['movieId'].tolist()
indices = pd.Series(movies.index, index=movies['movieId'])
#print(movies.head())
print(movies.dtypes)
print(titles)
print(indices)
# Out:
# movieId                 int64
# title                  object
# overview               object
# genres                 object
# keywords               object
# releaseDate    datetime64[ns]
# voteAverage           float64
# voteCount             float64
# posterPath             object
# director               object
# dtype: object
# [862, 8844, 15602, 31357, 11862, 949, 11860, 9091, 710, 9087, 12110, 21032, 10858, 1408, 524, 4584, 5, 9273, 11517, 8012, 1710, 9691, 12665, 451, 16420, 9263, 17015, 902, 37557, 9909, 63, 9598, 47018, 687, 33689, 9603, 34615, 31174, 11443, 35196, 9312, 577, 11861, 807, 10530, 8391, 629, 11448, 49133, 26441, 97406, 9089, 11010, 11359, 17182, 2054, 10607, 19760, 9536, 11525, 4482, 10634, 755, 11859, 28387, 48750, 20927, 36929, 9102, 27526, 9623, 46785, 400, 880, 8447, 10534, 17414, 13997, 2086, 9095, 12158, 9283, 9208, 40154, 406, 11062, 13685, 2045, 9614, 688, 11907, 10874, 197, 103, 33542, 43612, 16934, 10324, 78406, 55731, 11066, 11104, 2074, 27793, 32622, 11863, 9101, 39428, 9302, 11000, 16388, 9737, 30765, 10474, 22279, 30157, 568, 11780, 34996, 414, 649, 1873, 5894, 8839, 20649, 10329, 8963, 26564, 8068, 8512, 1572, 13552, 6520, 9073, 10428, 17447, 9886, 9482, 19326, 9344, 9071, 8973, 47608, 2293, 9070, 68274, 48787, 34574, 1642, 11472, 36196, 11980, 32646, 10533, 10802, 10149, 18402, 9348, 139408, 281, 5967, 47939, 36834, 9090, 3512, 52856, 77350, 9560, 9804, 31611, 65796, 26258, 50797, 19155, 76, 11017, 37141, 9382, 6715, 18256, 22625, 2292, 1909, 8984, 4954, 62488, 10531, 11929, 8467, 10451, 20156, 18395, 522, 397, 10525, 27985, 15789, 27303, 21183, 10954, 14275, 1024, 13701, 14819, 11777, 628, 87729, 18713, 6280, 9061, 37
# ['Animation Comedy Family', 'Adventure Fantasy Family', 'Romance Comedy', 'Comedy Drama Romance', 'Comedy', 'Action Crime Drama Thriller', 'Comedy Romance', 'Action Adventure Thriller', 'Adventure Action Thriller', 'Comedy Drama Romance', 'Comedy Horror', 'Family Animation Adventure', 'History Drama', 'Action Adventure', 'Drama Crime', 'Drama Romance', 'Crime Comedy', 'Crime Comedy Adventure', 'Action Comedy Crime', 'Comedy Thriller Crime', 'Drama Thriller', 'Action Adventure Crime Thriller', 'Drama Fantasy Science Fiction Thriller', 'Drama Romance', 'Drama', 'Comedy Drama Family', 'Drama Romance', 'Fantasy Science Fiction Adventure', 'Drama Crime', 'Drama Crime', 'Science Fiction Thriller Mystery', 'Fantasy Drama Comedy Family', 'History Drama Romance', 'Drama', 'Comedy Family Romance', 'Comedy Drama Romance', 'Drama', 'Drama War', 'Action Crime Drama History', 'Drama Romance', 'Action Fantasy', 'Fantasy Drama Comedy Thriller', 'Drama Romance', 'Crime Mystery Thriller', 'Adventure Animation Drama Family', 'Drama Romance', 'Drama Crime Thriller', 'Comedy Romance', 'Drama Foreign', 'Action Adventure Comedy Family', 'Drama', 'Comedy Drama Romance', 'Comedy Drama Romance', 'Adventure Family Fantasy', 'Drama Thriller', 'Music Drama Family', 'Comedy', 'Comedy Romance', 'Comedy', 'Action Science Fiction', 'Comedy Romance', 'Comedy', 'Horror Action Thriller Crime', 'Action Thriller Romance', 'Comedy Drama Romance', 'Drama History', 'Drama Romance', 'Comedy Family', 'Horror Science Fiction', 'Drama Thriller', 'Drama Thriller', 'Family Drama', 'Drama Crime', 'Drama Comedy', 'Drama Romance', 'Action Drama', 'Adventure Comedy Family', 'Comedy', 'Crime Drama Thriller', 'Drama Horror Thriller Romance', 'Comedy Horror Romance', 'Comedy Drama Romance', 'Action Adventure Drama Thriller', 'Comedy', 'Drama', 'Drama Thriller', 'Comedy Crime Drama', 'Drama Mystery Science Fiction Thriller', 'Comedy', 'Drama Romance', 'Drama Comedy Family', 'Action Comedy Music Family Adventure', 'Action Drama History War', 'Crime Drama', 'Crime Action Comedy Thriller', 'Comedy', 'Comedy Crime Drama', 'Comedy Romance', 'Comedy Drama', 'Action Adventure Comedy Drama Family', 'Comedy Romance', 'Drama Comedy Romance', 'Comedy Romance', 'Fantasy', 'Comedy Drama', 'Action Thriller Mystery Romance', 'Comedy', 'Drama', 'Drama Romance', 'Comedy', 'Comedy Drama Romance', 'Action Comedy Crime Thriller', 'Action Adventure Drama Family', 'Drama Crime', 'Romance Drama Comedy', 'Crime Comedy Drama Thriller', 'Drama', 'Adventure', 'Drama Horror', 'Action Crime Fantasy', 'Drama Romance', 'Drama Thriller', 'Comedy', 'Fantasy Comedy Family', 'Mystery Crime Drama', 'Action Adventure Drama Mystery Science Fiction Thriller', 'Action Thriller Drama', 'Documentary', 'Thriller Action Crime', 'Drama Mystery Thriller', 'Action Thriller', 'Action Comedy Crime Drama', 'Action Adventure Drama Romance', 'Adventure', 'Action Crime Thriller Drama', 'Comedy Drama Romance', 'Adventure Action Drama Science Fiction Thriller', 'Science Fiction', 'Comedy Drama', 'Drama Crime', 'Drama Comedy', 'Mystery Horror Thriller', 'Drama Family Romance', 'Romance Comedy', 'Action Adventure Science Fiction Family Fantasy', 'Comedy Drama Romance', 'Thriller Foreign', 'Horror Thriller', 'Crime Drama Mystery Thriller Action', 'Comedy', 'Comedy', 'Fantasy Horror Thriller', 'Drama', 'Drama History Romance', 'Drama', 'Comedy Drama', 'Comedy', 'Science Fiction Horror Action', 'Drama', 'Crime Drama Science Fiction Thriller', 'Drama Romance', 'Drama Fantasy', 'Drama Romance', 'Comedy', 'Action Thriller', 'Comedy Drama Family', 'Documentary', 'Drama Romance', 'Adventure Action', 'Drama', 'Action Western', 'Adventure Action Comedy Crime Family', 'Drama', 'Drama War', 'Drama Romance', 'Comedy', 'Drama Thriller', 'Comedy Drama', 'Drama Family', 'Thriller Drama Horror Mystery', 'Drama Family Romance', 'Comedy', 'Romance Drama Comedy', 'Drama Thriller Crime Mystery Romance', 'Action Adventure Thriller', 'Crime Comedy Fantasy', ' ...

# %%
for i in genres:
    temp = []

    for j in i:
        if j in genres_dict:
            temp.append(genres_dict[j])
    genres_n.append(' '.join(temp))

print(genres_n)
# Out:
# ['Animation Comedy Family', 'Adventure Fantasy Family', 'Romance Comedy', 'Comedy Drama Romance', 'Comedy', 'Action Crime Drama Thriller', 'Comedy Romance', 'Action Adventure Thriller', 'Adventure Action Thriller', 'Comedy Drama Romance', 'Comedy Horror', 'Family Animation Adventure', 'History Drama', 'Action Adventure', 'Drama Crime', 'Drama Romance', 'Crime Comedy', 'Crime Comedy Adventure', 'Action Comedy Crime', 'Comedy Thriller Crime', 'Drama Thriller', 'Action Adventure Crime Thriller', 'Drama Fantasy Science Fiction Thriller', 'Drama Romance', 'Drama', 'Comedy Drama Family', 'Drama Romance', 'Fantasy Science Fiction Adventure', 'Drama Crime', 'Drama Crime', 'Science Fiction Thriller Mystery', 'Fantasy Drama Comedy Family', 'History Drama Romance', 'Drama', 'Comedy Family Romance', 'Comedy Drama Romance', 'Drama', 'Drama War', 'Action Crime Drama History', 'Drama Romance', 'Action Fantasy', 'Fantasy Drama Comedy Thriller', 'Drama Romance', 'Crime Mystery Thriller', 'Adventure Animation Drama Family', 'Drama Romance', 'Drama Crime Thriller', 'Comedy Romance', 'Drama Foreign', 'Action Adventure Comedy Family', 'Drama', 'Comedy Drama Romance', 'Comedy Drama Romance', 'Adventure Family Fantasy', 'Drama Thriller', 'Music Drama Family', 'Comedy', 'Comedy Romance', 'Comedy', 'Action Science Fiction', 'Comedy Romance', 'Comedy', 'Horror Action Thriller Crime', 'Action Thriller Romance', 'Comedy Drama Romance', 'Drama History', 'Drama Romance', 'Comedy Family', 'Horror Science Fiction', 'Drama Thriller', 'Drama Thriller', 'Family Drama', 'Drama Crime', 'Drama Comedy', 'Drama Romance', 'Action Drama', 'Adventure Comedy Family', 'Comedy', 'Crime Drama Thriller', 'Drama Horror Thriller Romance', 'Comedy Horror Romance', 'Comedy Drama Romance', 'Action Adventure Drama Thriller', 'Comedy', 'Drama', 'Drama Thriller', 'Comedy Crime Drama', 'Drama Mystery Science Fiction Thriller', 'Comedy', 'Drama Romance', 'Drama Comedy Family', 'Action Comedy Music Family Adventure', 'Action Drama History War', 'Crime Drama', 'Crime Action Comedy Thriller', 'Comedy', 'Comedy Crime Drama', 'Comedy Romance', 'Comedy Drama', 'Action Adventure Comedy Drama Family', 'Comedy Romance', 'Drama Comedy Romance', 'Comedy Romance', 'Fantasy', 'Comedy Drama', 'Action Thriller Mystery Romance', 'Comedy', 'Drama', 'Drama Romance', 'Comedy', 'Comedy Drama Romance', 'Action Comedy Crime Thriller', 'Action Adventure Drama Family', 'Drama Crime', 'Romance Drama Comedy', 'Crime Comedy Drama Thriller', 'Drama', 'Adventure', 'Drama Horror', 'Action Crime Fantasy', 'Drama Romance', 'Drama Thriller', 'Comedy', 'Fantasy Comedy Family', 'Mystery Crime Drama', 'Action Adventure Drama Mystery Science Fiction Thriller', 'Action Thriller Drama', 'Documentary', 'Thriller Action Crime', 'Drama Mystery Thriller', 'Action Thriller', 'Action Comedy Crime Drama', 'Action Adventure Drama Romance', 'Adventure', 'Action Crime Thriller Drama', 'Comedy Drama Romance', 'Adventure Action Drama Science Fiction Thriller', 'Science Fiction', 'Comedy Drama', 'Drama Crime', 'Drama Comedy', 'Mystery Horror Thriller', 'Drama Family Romance', 'Romance Comedy', 'Action Adventure Science Fiction Family Fantasy', 'Comedy Drama Romance', 'Thriller Foreign', 'Horror Thriller', 'Crime Drama Mystery Thriller Action', 'Comedy', 'Comedy', 'Fantasy Horror Thriller', 'Drama', 'Drama History Romance', 'Drama', 'Comedy Drama', 'Comedy', 'Science Fiction Horror Action', 'Drama', 'Crime Drama Science Fiction Thriller', 'Drama Romance', 'Drama Fantasy', 'Drama Romance', 'Comedy', 'Action Thriller', 'Comedy Drama Family', 'Documentary', 'Drama Romance', 'Adventure Action', 'Drama', 'Action Western', 'Adventure Action Comedy Crime Family', 'Drama', 'Drama War', 'Drama Romance', 'Comedy', 'Drama Thriller', 'Comedy Drama', 'Drama Family', 'Thriller Drama Horror Mystery', 'Drama Family Romance', 'Comedy', 'Romance Drama Comedy', 'Drama Thriller Crime Mystery Romance', 'Action Adventure Thriller', 'Crime Comedy Fantasy', ' ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=1, stop_words='english')
tfidf_matrix = tf.fit_transform(genres_n)
print(tfidf_matrix.shape)
# Out:
# (70218, 387)

# %%
from sklearn.metrics.pairwise import linear_kernel
#cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
#cosine_sim[:4, :4]
idx = 0
scores = linear_kernel(tfidf_matrix[idx:idx+1], tfidf_matrix).flatten()
print(scores)
# Out:
# [1.         0.12655454 0.07420847 ... 0.06818242 0.         0.        ]

# %%
def genre_recommendations(title):
    idx = indices[title]

    sim_scores = linear_kernel(tfidf_matrix[idx:idx+1], tfidf_matrix).flatten()
    sim_scores = list(enumerate(sim_scores))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:3]
    movie_indices = [i[0] for i in sim_scores]
    return [titles[i] for i in movie_indices]

genre_recommendations(212)
# Out:
# [36593, 9401]
